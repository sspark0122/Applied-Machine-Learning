# %%
import numpy
import matplotlib.pyplot as plt

loss = numpy.array([0.114128, 0.0146139, 0.0098740, 0.0084569, 0.007745229119, 0.00686882288, 0.0066378097, 0.00635056, 0.00605428877, 0.00578838507, 0.005641337839])
iteration = numpy.array([1, 498, 998, 1498, 1999, 2498, 2998, 3498, 3998, 4498, 4999])

plt.title("Loss vs iterations")
plt.xlabel("Iteration number")
plt.ylabel("Loss value")
plt.plot(iteration, loss)
